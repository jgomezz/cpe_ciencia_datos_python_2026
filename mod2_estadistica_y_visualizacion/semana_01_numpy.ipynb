# %% [markdown]
# ## Módulo 2 : Estadística y Visualización de Datos
# #### Sesión : 01
# #### Fecha : 01/08/20206
# #### Autor : Jaime Gómez

# %%
print("Módulo 2 : Estadística y Visualización de Datos")
# Out:
# Módulo 2 : Estadística y Visualización de Datos
