# %% [markdown]
# # Semana 1: Transformación de datos

# %% [markdown]
# Link Automobile Dataset: https://www.kaggle.com/datasets/toramky/automobile-dataset

# %%
'''
Curso: Análisis de Datos con Python
Sesión 1: Transformación de datos
Fecha: 13/12/2025
Actualización : 28/08/2026
Autor: José Espinoza Melgarejo / Jaime Gómez 
'''

import pandas as pd

filename = "dataset/autos.csv"

headers = ["symboling","normalized-losses","make","fuel-type","aspiration",
           "num-of-doors","body-style","drive-wheels","engine-location","wheel-base",
           "length","width","height","curb-weight","engine-type","num-of-cylinders",
           "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
           "peak-rpm","city-mpg","highway-mpg","price"]

df = pd.read_csv(filename, names=headers)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ## Descripción de las variables
#
# - 'symboling' : Nivel de riesgo del seguro , de menor riesgo (-3) a mayor riesgto (3)
# - "normalized-losses" : Es la perdida del pago promedio del seguro del auto por año y representa la perdida por año del auto. El valor oscila entre 65 a 256
# - 'make' : Marca
# - "aspiration" : Como el motor de combustión interno trabaja , puede ser estandar (std) o turbo
# - 'num-of-doors' : Número de puertas
# - "body-style" : Carroceria
# - 'drive-wheels' : Tracción de las ruedas
# - 'engine-location' : Localización del motor
# - 'wheel-base' : Distancia entre ejes
# - 'length' : Longitud
# - 'width' : Ancho
# - 'height': Alto
# - 'curb-weight' : Peso del auto con equipación completa
# - 'engine-type': Tipo de motor
# - 'num-of-cylinders' : Número de cilindros
# - 'engine-size' : Tamaño del motor
# - 'fuel-system' : Sistema de combustible
# - 'bore' : Diámetro interno de los cilindros del motor, en pulgadas.
# - 'stroke' : Distancia recorrida por el pistón durante cada ciclo
# - 'compression-ratio': Ratio de comprensión
# - 'horsepower' : Caballos de potencia
# - 'horsepower-binned' : Caballos de potencia convertidos en una variable categórica
# - 'peak-rpm' : RPM pico
# - 'city-mpg' : consumo en la ciudad en millas por galon
# - 'highway-mpg' : consumo en autopista en millas por galon
# - 'price' : Precio
# - 'city-L/100km' :  consumo en la ciudad en litros por kilometro
# - 'diesel' : variable dummy para consumo por petróleo
# - 'gas': variable dummy para consumo por gasoina

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
df[['symboling', 'normalized-losses', 'make']].head()
# Out:
#    symboling normalized-losses         make
# 0          3                 ?  alfa-romero
# 1          3                 ?  alfa-romero
# 2          1                 ?  alfa-romero
# 3          2               164         audi
# 4          2               164         audi

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df.describe().columns
# Out:
# Index(['symboling', 'wheel-base', 'length', 'width', 'height', 'curb-weight',
#        'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg'],
#       dtype='object')

# %%
df.describe().round(2)
# Out:
#        symboling  wheel-base  length   width  height  curb-weight  \
# count     205.00      205.00  205.00  205.00  205.00       205.00
# mean        0.83       98.76  174.05   65.91   53.72      2555.57
# std         1.25        6.02   12.34    2.15    2.44       520.68
# min        -2.00       86.60  141.10   60.30   47.80      1488.00
# 25%         0.00       94.50  166.30   64.10   52.00      2145.00
# 50%         1.00       97.00  173.20   65.50   54.10      2414.00
# 75%         2.00      102.40  183.10   66.90   55.50      2935.00
# max         3.00      120.90  208.10   72.30   59.80      4066.00
#
#        engine-size  compression-ratio  city-mpg  highway-mpg
# count       205.00             205.00    205.00       205.00
# mean        126.91              10.14     25.22        30.75
# std          41.64               3.97      6.54         6.89
# min          61.00               7.00     13.00        16.00
# 25%          97.00               8.60     19.00        25.00
# ...

# %%
df["engine-size"].describe().round(2)
# Out:
# count    205.00
# mean     126.91
# std       41.64
# min       61.00
# 25%       97.00
# 50%      120.00
# 75%      141.00
# max      326.00
# Name: engine-size, dtype: float64

# %%
# Una vista de la data
dfx = df[["symboling","normalized-losses","make","fuel-type","price"]]
dfx.head()
# Out:
#    symboling normalized-losses         make fuel-type  price
# 0          3                 ?  alfa-romero       gas  13495
# 1          3                 ?  alfa-romero       gas  16500
# 2          1                 ?  alfa-romero       gas  16500
# 3          2               164         audi       gas  13950
# 4          2               164         audi       gas  17450

# %%
# Una copia de la data
dfx_new = dfx.copy()
dfx_new.head()
# Out:
#    symboling normalized-losses         make fuel-type  price
# 0          3                 ?  alfa-romero       gas  13495
# 1          3                 ?  alfa-romero       gas  16500
# 2          1                 ?  alfa-romero       gas  16500
# 3          2               164         audi       gas  13950
# 4          2               164         audi       gas  17450

# %%
# Solo mostrar la data
dfx
# Out:
#      symboling normalized-losses         make fuel-type  price
# 0            3                 ?  alfa-romero       gas  13495
# 1            3                 ?  alfa-romero       gas  16500
# 2            1                 ?  alfa-romero       gas  16500
# 3            2               164         audi       gas  13950
# 4            2               164         audi       gas  17450
# ..         ...               ...          ...       ...    ...
# 200         -1                95        volvo       gas  16845
# 201         -1                95        volvo       gas  19045
# 202         -1                95        volvo       gas  21485
# 203         -1                95        volvo    diesel  22470
# 204         -1                95        volvo       gas  22625
#
# [205 rows x 5 columns]

# %% [markdown]
# ## Procedimiento para gestionar datos perdidos

# %% [markdown]
# ### Identificar datos perdidos

# %%
key_data_missing = "?"
DATA_MISSING = "?"

# Datos válidos del precio de los autos
nro_price_validate = df['price'].loc[df['price'] != DATA_MISSING].count()
print(nro_price_validate)
# Out:
# 201

# %%
# Datos perdidos del precio de los autos
nro_price_missing = df['price'].loc[df['price'] == DATA_MISSING].count()
print(nro_price_missing)

# print(len(df))
# Out:
# 4

# %%
nro_price_reg = df['price'].count()
nro_price_reg
# Out:
# np.int64(205)

# %%
df["price"].describe()
# Out:
# count     205
# unique    187
# top         ?
# freq        4
# Name: price, dtype: object

# %%
df.count()
# Out:
# symboling            205
# normalized-losses    205
# make                 205
# fuel-type            205
# aspiration           205
# num-of-doors         205
# body-style           205
# drive-wheels         205
# engine-location      205
# wheel-base           205
# length               205
# width                205
# height               205
# curb-weight          205
# engine-type          205
# num-of-cylinders     205
# engine-size          205
# fuel-system          205
# bore                 205
# stroke               205
# compression-ratio    205
# horsepower           205
# peak-rpm             205
# city-mpg             205
# highway-mpg          205
# price                205
# dtype: int64

# %% [markdown]
# ## Porcentaje de datos perdidos

# %%
nro_price_validate = df['price'].loc[df['price'] != DATA_MISSING].count()
print(nro_price_validate)

print("-----------------------------------------------------------")
nro_price_missing = df['price'].loc[df['price'] == DATA_MISSING].count()
print(nro_price_missing)

print("-----------------------------------------------------------")
print("Porcentaje de válidos =", nro_price_missing/nro_price_validate*100,"%")
# Out:
# 201
# -----------------------------------------------------------
# 4
# -----------------------------------------------------------
# Porcentaje de válidos = 1.9900497512437811 %

# %%
# ¿Podemos decir que la variable width tiene datos perdidos?
nro_width_validate = df['width'].loc[df['width'] != DATA_MISSING].count()

print(nro_width_validate)
# Out:
# 205

# %% [markdown]
# ## Representando valores nulos y descargando data

# %%
import numpy as np
# Representación de un dato faltante
print("Valor nulo =",np.nan)
# Out:
# Valor nulo = nan

# %%
# Reemplazar "?" a valor nulo (np.nan)
df.replace(DATA_MISSING, np.nan, inplace=True)
df.head(10)

# TO DO : Se debe reemplazar todos los datos incompletos que se considerar nulos con np.nan
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2               NaN         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1               NaN         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0               NaN         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Descargar datos tratadps en formato CSV
df.to_csv("output/data_preparada.csv")

# %% [markdown]
# ## Identificando variables con datos perdidos

# %%
# Variables con datos perdidos
missing_data = df.isnull()
missing_data.head(10)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
# 5      False               True  False      False       False         False
# 6      False              False  False      False       False         False
# 7      False               True  False      False       False         False
# 8      False              False  False      False       False         False
# 9      False               True  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# ...

# %%
missing_data['normalized-losses'].head(10)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# 9     True
# Name: normalized-losses, dtype: bool

# %%
md = missing_data['normalized-losses'].value_counts()
md
# Out:
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64

# %%
# Cantidad de tipos de valores que tiene el campo "normalized-losses"
nro_tipos = len(missing_data['normalized-losses'].value_counts())
print(f" La variable 'normalized-losses' tiene {nro_tipos} tipos de datos")
# Out:
#  La variable 'normalized-losses' tiene 2 tipos de datos

# %%
# ¿Cuanto tipos de combustible existe de acuerdo a la variable fuel-type?
df['fuel-type'].value_counts()
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
# ¿Cuanto tipos de motor existe de acuerdo a la variable engine-type?
df['engine-type'].value_counts()
# Out:
# engine-type
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64

# %%
# Contar datos perdidos por columnas.  
for column in list(missing_data.columns):
    if len(missing_data[column].value_counts()) > 1:
        print(f"Variable = {column}")             # nueva
        print(missing_data[column].value_counts())
        print("")
# Out:
# Variable = normalized-losses
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64
#
# Variable = num-of-doors
# num-of-doors
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = bore
# bore
# False    201
# True       4
# Name: count, dtype: int64
#
# Variable = stroke
# stroke
# False    201
# True       4
# Name: count, dtype: int64
#
# Variable = horsepower
# horsepower
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = peak-rpm
# peak-rpm
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = price
# price
# False    201
# True       4
# Name: count, dtype: int64

# %%
# Contar datos perdidos por columnas
for column in list(missing_data.columns):
     if len(missing_data[column].value_counts()) == 2:
        print(f"Variable = {column}")
        print(missing_data[column].value_counts())
        print("")
# Out:
# Variable = normalized-losses
# normalized-losses
# False    164
# True      41
# Name: count, dtype: int64
#
# Variable = num-of-doors
# num-of-doors
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = bore
# bore
# False    201
# True       4
# Name: count, dtype: int64
#
# Variable = stroke
# stroke
# False    201
# True       4
# Name: count, dtype: int64
#
# Variable = horsepower
# horsepower
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = peak-rpm
# peak-rpm
# False    203
# True       2
# Name: count, dtype: int64
#
# Variable = price
# price
# False    201
# True       4
# Name: count, dtype: int64

# %% [markdown]
# ## Contando datos perdidos por columnas

# %%
nro_reg = len(df)

#for column in missing_data.columns.values.tolist():
for column in list(missing_data.columns):
    s = missing_data[column].value_counts()
    #print(s)
    if s.iloc[0] != nro_reg: 
       print(f"La variable {column} tiene {s.iloc[0]} datos completos y {s.iloc[1]} datos faltantes")
# Out:
# La variable normalized-losses tiene 164 datos completos y 41 datos faltantes
# La variable num-of-doors tiene 203 datos completos y 2 datos faltantes
# La variable bore tiene 201 datos completos y 4 datos faltantes
# La variable stroke tiene 201 datos completos y 4 datos faltantes
# La variable horsepower tiene 203 datos completos y 2 datos faltantes
# La variable peak-rpm tiene 203 datos completos y 2 datos faltantes
# La variable price tiene 201 datos completos y 4 datos faltantes

# %%
nro_reg = len(df)

for column in missing_data.columns.values.tolist():
    s = missing_data[column].value_counts()
    # print(s)
    # print(type(s))
    if s.iloc[0] != nro_reg:
       print("La variable", column, "tiene", s.iloc[0] ,"datos completos")
# Out:
# La variable normalized-losses tiene 164 datos completos
# La variable num-of-doors tiene 203 datos completos
# La variable bore tiene 201 datos completos
# La variable stroke tiene 201 datos completos
# La variable horsepower tiene 203 datos completos
# La variable peak-rpm tiene 203 datos completos
# La variable price tiene 201 datos completos

# %%
# Otra alternativa
p = (missing_data.sum()/len(missing_data)*100).sort_values(ascending=False)
p.head()
# Out:
# normalized-losses    20.00000
# price                 1.95122
# stroke                1.95122
# bore                  1.95122
# peak-rpm              0.97561
# dtype: float64

# %% [markdown]
# ## Tratamiento de datos faltantes

# %%
# Mostrar tipos de datos asignados al momento de cargar el DataFrame
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
'''# No se puede ejecutar directamente porque los datos son cadena
df['price'].mean()'''
# Out:
# "# No se puede ejecutar directamente porque los datos son cadena\ndf['price'].mean()"

# %%
## Convertir la variable price a tipo float
# Paso 1: Convertir la variable price a tipo float astype('float')
# Paso 2: Calcular el promedio de la variable price
df['price'].astype('float').mean()
# Out:
# np.float64(13207.129353233831)

# %%
df[['price']].dtypes
# Out:
# price    object
# dtype: object

# %%
# Imputación para la variable bore
# Se va a reemplazar el dato faltante con el promedio 
avg_bore = df['bore'].astype('float').mean()
avg_bore = round(avg_bore,4)      
print(f"El promedio de la variable bore es {avg_bore} ")
#df["bore"].replace(np.nan, avg_bore, inplace=True)
df["bore"] = df["bore"].replace(np.nan, avg_bore)
# Out:
# El promedio de la variable bore es 3.3298

# %%
# Imputación para la variable normalized-losses
avg_norm_loss = df["normalized-losses"].astype("float").mean()
avg_norm_loss = round(avg_norm_loss,4)    
print("El promedio de normalized-losses es", avg_norm_loss)

# df["normalized-losses"].replace(np.nan, avg_norm_loss, inplace=True)
# Usar fillna en lugar de replace
df["normalized-losses"] = df["normalized-losses"].fillna(avg_norm_loss)
# Out:
# El promedio de normalized-losses es 122.0

# %%
# Imputación para la variable horsepower
avg_horsepower = df['horsepower'].astype('float').mean()
avg_horsepower = round(avg_horsepower,4)
print("El promedio de la variable horsepower es", avg_horsepower)
# df["horsepower"].replace(np.nan, avg_horsepower, inplace=True)
df["horsepower"] = df["horsepower"].fillna(avg_horsepower)
# Out:
# El promedio de la variable horsepower es 104.2562

# %%
# Imputación para la variable peak-rpm
avg_peak_rpm=df['peak-rpm'].astype('float').mean()
avg_peak_rpm = round(avg_peak_rpm,4)
print("El promedio de la variable peak-rpm es", avg_peak_rpm)
#df["peak-rpm"].replace(np.nan, avg_peak_rpm, inplace=True)
df["peak-rpm"] = df["peak-rpm"].fillna(avg_peak_rpm)
# Out:
# El promedio de la variable peak-rpm es 5125.3695

# %%
# Promedio para un grupo de variables
lista = ["normalized-losses","stroke","horsepower","peak-rpm"]
for column in lista:
    avg = df[column].astype('float').mean(axis=0)
    avg = round(avg,4)
    #df[column].replace(np.nan, avg, inplace=True)
    df[column] = df[column].fillna(avg)
    print(f"El promedio de la variable {column} es {avg}")
# Out:
# El promedio de la variable normalized-losses es 122.0
# El promedio de la variable stroke es 3.2554
# El promedio de la variable horsepower es 104.2562
# El promedio de la variable peak-rpm es 5125.3695

# %%
# Imputación de las variables stroke, peak-rpm, horsepower y normalized-losses
for i in ["stroke","peak-rpm","horsepower","normalized-losses"]:
    avg = df[i].astype("float").mean()
    #df[i].replace(np.nan, avg, inplace=True)
    df[i] = df[i].fillna(avg)

    
# df[["stroke","peak-rpm","horsepower","normalized-losses"]]

# %%
# Variables con datos perdidos
missing_data = df.isnull()
missing_data.head()
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False              False  False      False       False         False
# 1      False              False  False      False       False         False
# 2      False              False  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %%
# Porcentaje de valores perdidos (primera forma)
(missing_data.sum()/len(missing_data)*100).sort_values(ascending=False)
# Out:
# price                1.95122
# num-of-doors         0.97561
# engine-type          0.00000
# highway-mpg          0.00000
# city-mpg             0.00000
# peak-rpm             0.00000
# horsepower           0.00000
# compression-ratio    0.00000
# stroke               0.00000
# bore                 0.00000
# fuel-system          0.00000
# engine-size          0.00000
# num-of-cylinders     0.00000
# symboling            0.00000
# normalized-losses    0.00000
# height               0.00000
# width                0.00000
# length               0.00000
# wheel-base           0.00000
# engine-location      0.00000
# drive-wheels         0.00000
# body-style           0.00000
# aspiration           0.00000
# fuel-type            0.00000
# make                 0.00000
# curb-weight          0.00000
# dtype: float64

# %%
# Porcentaje de valores perdidos (segunda forma)
nro_reg = len(df)

for column in missing_data.columns.values.tolist():
    s = missing_data[column].value_counts()
    if s.iloc[0] != nro_reg:
       print("La variable", column, "tiene", s.iloc[0] ,"datos completos")
       percentaje_missing_data = ((nro_reg - s.iloc[0])/nro_reg)*100
       print(round(percentaje_missing_data,0),"%")
# Out:
# La variable num-of-doors tiene 203 datos completos
# 1.0 %
# La variable price tiene 201 datos completos
# 2.0 %

# %% [markdown]
# ### Imputación por la moda

# %%
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %%
# Buscando la moda
print("Frecuencias por categoría: \n",df["num-of-doors"].value_counts())

# Otra manera de visualizar la moda
print("-----------------------------------------------------------")
mode = df['num-of-doors'].value_counts().idxmax()
print("Moda =",mode)

# Se reemplaza con la moda
print("-----------------------------------------------------------")
#df["num-of-doors"].replace(np.nan, mode, inplace=True)
df["num-of-doors"] = df["num-of-doors"].fillna(mode)


# Se obtiene las variables con datos perdidos
missing_data = df.isnull()
(missing_data.sum()/len(missing_data)*100).sort_values(ascending=False)
# Out:
# Frecuencias por categoría:
#  num-of-doors
# four    114
# two      89
# Name: count, dtype: int64
# -----------------------------------------------------------
# Moda = four
# -----------------------------------------------------------
# price                1.95122
# normalized-losses    0.00000
# highway-mpg          0.00000
# city-mpg             0.00000
# peak-rpm             0.00000
# horsepower           0.00000
# compression-ratio    0.00000
# stroke               0.00000
# bore                 0.00000
# fuel-system          0.00000
# engine-size          0.00000
# num-of-cylinders     0.00000
# engine-type          0.00000
# symboling            0.00000
# height               0.00000
# width                0.00000
# length               0.00000
# wheel-base           0.00000
# engine-location      0.00000
# drive-wheels         0.00000
# body-style           0.00000
# num-of-doors         0.00000
# aspiration           0.00000
# fuel-type            0.00000
# ...

# %%
# Eliminando las filas que tengan datos faltantes en la variable price
row = 0
df.dropna(subset=["price"], axis=row, inplace=True)

# Reseteando el índice porque se han borrado 4 líneas
df.reset_index(drop=True, inplace=True)

len(df)
# Out:
# 201

# %%
# Contar los valores nulos por variable
missing_data = df.isnull()
print(missing_data.sum())

# Grabar datos en formato CSV
df.to_csv("output/data_imputada.csv")

# Leer datos descargados en un data frame
print("-----------------------------------------------------------")
dfx = pd.read_csv("output/data_imputada.csv")
print(dfx)
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64
# -----------------------------------------------------------
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3              122.0  alfa-romero       gas
# 1             1          3              122.0  alfa-romero       gas
# ...

# %% [markdown]
# ### Corrección de formato de datos

# %%
# Observar tipo de datos por variable
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
# Cambiar tipo de dato para una variable
print("-----------------------------------------------------------")
df["price"] = df["price"].astype("float")
df.dtypes
# Out:
# -----------------------------------------------------------
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
# Cambiar formato para un grupo de variables
df["bore"] = df["bore"].astype("float")
df["peak-rpm"] = df["peak-rpm"].astype("float")
df["stroke"] = df["stroke"].astype("float")
df["normalized-losses"] = df["normalized-losses"].astype("int")

# %%
# Automatizondo las conversiones
variables = ["bore", "stroke", "peak-rpm"]
for i in variables:
    df[i] = df[i].astype("float")
df["normalized-losses"] = df["normalized-losses"].astype("int")
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %% [markdown]
# ## Formateando datos

# %%
import random

# Definir el rango de fechas
inicio = pd.to_datetime('2025-01-01 00:00:00')
fin = pd.to_datetime('2025-12-31 23:59:59')

# Función para generar una fecha y hora aleatoria dentro del rango
def fecha_hora_aleatoria(inicio, fin):
    delta = fin - inicio
    int_delta = int(delta.total_seconds())
    aleatorio_segundos = random.randint(0, int_delta)
    return inicio + pd.to_timedelta(aleatorio_segundos, unit='s')

# Generar la columna de fechas y horas aleatorias
df['date_time'] = [fecha_hora_aleatoria(inicio, fin) for _ in range(len(df))]
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %%
import datetime
df["date_time_new1"] = df["date_time"].apply(lambda x: x.strftime("%d-%m-%Y %H:%M:%S"))

df["date_time_new2"] = df["date_time"].apply(lambda x: x.strftime("%d-%m-%y %H:%M:%S"))

df["date_time_new3"] = df["date_time"].apply(lambda x: x.strftime("%m-%Y %H:%M:%S"))

df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
df["day"] = df["date_time"].dt.day
df["day_week"] = df["date_time"].dt.day_name()
df["month"] = df["date_time"].dt.month
df["year"] = df["date_time"].dt.year
df["time"] = df["date_time"].dt.time
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#      price           date_time       date_time_new1     date_time_new2  \
# ...

# %% [markdown]
# ### Normalización de datos

# %%
# Obtenemos el mayor valor
max1 = df['length'].max()

# Obtenemos el menor valor
min1 = df['length'].min()

# Mostramos los datos
print("-----------------------------------------------------------")
print(df[['length']].head())

print("-----------------------------------------------------------")
# Reemplazamos (valor original - mínimo)/(máximo - mínimo)
df['length_norm1'] = (df['length'] - min1)/(max1 - min1)
df[['length_norm1']].head()
# Out:
# -----------------------------------------------------------
#    length
# 0   168.8
# 1   168.8
# 2   171.2
# 3   176.6
# 4   176.6
# -----------------------------------------------------------
#    length_norm1
# 0      0.413433
# 1      0.413433
# 2      0.449254
# 3      0.529851
# 4      0.529851

# %%
# Obtenemos el mayor valor
max2 = df['width'].max()

# Obtenemos el menor valor
min2 = df['width'].min()

# Mostramos los datos
print("-----------------------------------------------------------")
print(df[['width']].head())

print("-----------------------------------------------------------")
# Reemplazamos (valor original - mínimo)/(máximo - mínimo)
df['width_norm1'] = (df['width']- min2)/(max2 - min2)
print(df[['width_norm1']].head())
# Out:
# -----------------------------------------------------------
#    width
# 0   64.1
# 1   64.1
# 2   65.5
# 3   66.2
# 4   66.4
# -----------------------------------------------------------
#    width_norm1
# 0     0.324786
# 1     0.324786
# 2     0.444444
# 3     0.504274
# 4     0.521368

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
A = scaler.fit_transform(df[["length"]])
B = scaler.fit_transform(df[["width"]])
df["length_norm2"] = pd.DataFrame(data=A)
df["width_norm2"] = pd.DataFrame(data=B)
print(df[['length_norm2','width_norm2']].head())
# Out:
#    length_norm2  width_norm2
# 0      0.413433     0.324786
# 1      0.413433     0.324786
# 2      0.449254     0.444444
# 3      0.529851     0.504274
# 4      0.529851     0.521368

# %%
# Convirtiendo mpg a km (0.4251 multiplicado por mpg)
print("-----------------------------------------------------------")
df['city-km'] = round(df["city-mpg"]*0.4251,3)
print(df[['city-mpg','city-km']].head())

print("-----------------------------------------------------------")
df['highway-km'] = round(df["highway-mpg"]*0.4251,3)
print(df[['highway-mpg','highway-km']].head())

print("-----------------------------------------------------------")
df.columns
# Out:
# -----------------------------------------------------------
#    city-mpg  city-km
# 0        21    8.927
# 1        21    8.927
# 2        19    8.077
# 3        24   10.202
# 4        18    7.652
# -----------------------------------------------------------
#    highway-mpg  highway-km
# 0           27      11.478
# 1           27      11.478
# 2           26      11.053
# 3           30      12.753
# 4           22       9.352
# -----------------------------------------------------------
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price', 'date_time', 'date_time_new1', 'date_time_new2',
# ...

# %% [markdown]
# ## Variables numéricas y categóricas

# %% [markdown]
# ### Estandarización de datos

# %%
# Obtenemos la media
mean1 = df['length'].mean()
mean2 = df['width'].mean()

# Obtenemos la desviación estándar poblacional (ddof=0)
std1 = df['length'].std(ddof=0)
std2 = df['width'].std(ddof=0)

# Mostramos los datos
print("-----------------------------------------------------------")
print(df[['length','width']].head())

# Reemplazamos (valor original - media)/(desviación estándar)
df['length_std1'] = (df['length'] - mean1)/std1
df['width_std1'] = (df['width'] - mean2)/std2
print(df[['length_std1', 'width_std1']])
# Out:
# -----------------------------------------------------------
#    length  width
# 0   168.8   64.1
# 1   168.8   64.1
# 2   171.2   65.5
# 3   176.6   66.2
# 4   176.6   66.4
#      length_std1  width_std1
# 0      -0.439409   -0.853460
# 1      -0.439409   -0.853460
# 2      -0.244152   -0.185597
# 3       0.195176    0.148335
# 4       0.195176    0.243744
# ..           ...         ...
# 196     1.187733    1.436357
# 197     1.187733    1.388653
# 198     1.187733    1.436357
# 199     1.187733    1.436357
# 200     1.187733    1.436357
#
# [201 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
A = scaler.fit_transform(df[["length"]])
B = scaler.fit_transform(df[["width"]])
df["length_std2"] = pd.DataFrame(data=A)
df["width_std2"] = pd.DataFrame(data=B)
print(df[['length_std2','width_std2']])
# Out:
#      length_std2  width_std2
# 0      -0.439409   -0.853460
# 1      -0.439409   -0.853460
# 2      -0.244152   -0.185597
# 3       0.195176    0.148335
# 4       0.195176    0.243744
# ..           ...         ...
# 196     1.187733    1.436357
# 197     1.187733    1.388653
# 198     1.187733    1.436357
# 199     1.187733    1.436357
# 200     1.187733    1.436357
#
# [201 rows x 2 columns]

# %% [markdown]
# ## Particionamiento mediante un histograma

# %%
# Ver tipo de variable
df[["horsepower"]].dtypes
# Out:
# horsepower    object
# dtype: object

# %%
# Se convierte a enteros
df["horsepower"] = df["horsepower"].astype(int)
df[["horsepower"]].dtypes
# Out:
# horsepower    int64
# dtype: object

# %%
# Graficando histograma para horsepower
import matplotlib.pyplot as plt

plt.hist(df["horsepower"]) # El valor por defecto bins = 10
plt.xlabel("horsepower")
plt.ylabel("Número de veces")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
# Generar puntos de corte 
minimo = df["horsepower"].min()
maximo = df["horsepower"].max()
punto_de_corte = 4
bins = np.linspace(minimo,maximo,punto_de_corte)
print("Particiones =",bins)

print("-----------------------------------------------------------")
bins_custom = [48, 100, 200, 262] # cortes personalizados
group_names = ['Bajo', 'Medio', 'Alto']

df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names)
df['horsepower-binned-custom'] = pd.cut(df['horsepower'], bins_custom, labels=group_names)
df[['horsepower','horsepower-binned','horsepower-binned-custom']].head()
# Out:
# Particiones = [ 48.         119.33333333 190.66666667 262.        ]
# -----------------------------------------------------------
#    horsepower horsepower-binned horsepower-binned-custom
# 0         111              Bajo                    Medio
# 1         111              Bajo                    Medio
# 2         154             Medio                    Medio
# 3         102              Bajo                    Medio
# 4         115              Bajo                    Medio

# %%
df["horsepower-binned"].value_counts()
# Out:
# horsepower-binned
# Bajo     152
# Medio     43
# Alto       5
# Name: count, dtype: int64

# %%
df["horsepower-binned-custom"].value_counts()
# Out:
# horsepower-binned-custom
# Bajo     108
# Medio     88
# Alto       4
# Name: count, dtype: int64

# %%
plt.bar(group_names, df["horsepower-binned"].value_counts())
plt.xlabel("horsepower")
plt.ylabel("Número de veces")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
plt.hist(df["horsepower"], bins = 3)
plt.xlabel("horsepower")
plt.ylabel("Número de veces")
plt.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %% [markdown]
# ### Variables dummy

# %%
df[["fuel-type"]].dtypes
# Out:
# fuel-type    object
# dtype: object

# %%
df["fuel-type"].head()
# Out:
# 0    gas
# 1    gas
# 2    gas
# 3    gas
# 4    gas
# Name: fuel-type, dtype: object

# %%
df["fuel-type"].value_counts()
# Out:
# fuel-type
# gas       181
# diesel     20
# Name: count, dtype: int64

# %%
dummy_variable_1 = pd.get_dummies(df["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %%
print("-----------------------------------------------------------")
dummy_variable_1.rename(columns={'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, 
                        inplace=True)
dummy_variable_1.head()
# Out:
# -----------------------------------------------------------
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %%
df = pd.concat([df, dummy_variable_1], axis=1)
df.drop("fuel-type", axis = 1, inplace=True)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  city-km  \
# 0  convertible          rwd           front        88.6   168.8  ...    8.927
# 1  convertible          rwd           front        88.6   168.8  ...    8.927
# 2    hatchback          rwd           front        94.5   171.2  ...    8.077
# 3        sedan          fwd           front        99.8   176.6  ...   10.202
# 4        sedan          4wd           front        99.4   176.6  ...    7.652
#
#    highway-km  length_std1 width_std1 length_std2  width_std2  \
# ...

# %%
dummy_variable_2 = pd.get_dummies(df["aspiration"])
dummy_variable_2.rename(columns={'std':'aspiration-type-standar', 'turbo':'aspiration-type-turbo'}, 
                        inplace=True)
df = pd.concat([df, dummy_variable_2], axis=1)
df[["aspiration","aspiration-type-standar","aspiration-type-turbo"]].tail(10)
# Out:
#     aspiration  aspiration-type-standar  aspiration-type-turbo
# 191        std                     True                  False
# 192        std                     True                  False
# 193        std                     True                  False
# 194      turbo                    False                   True
# 195      turbo                    False                   True
# 196        std                     True                  False
# 197      turbo                    False                   True
# 198        std                     True                  False
# 199      turbo                    False                   True
# 200      turbo                    False                   True

# %%
df = pd.concat([df, dummy_variable_2], axis=1)
df.drop("aspiration", axis = 1, inplace=True)
df
# Out:
#      symboling  normalized-losses         make num-of-doors   body-style  \
# 0            3                122  alfa-romero          two  convertible
# 1            3                122  alfa-romero          two  convertible
# 2            1                122  alfa-romero          two    hatchback
# 3            2                164         audi         four        sedan
# 4            2                164         audi         four        sedan
# ..         ...                ...          ...          ...          ...
# 196         -1                 95        volvo         four        sedan
# 197         -1                 95        volvo         four        sedan
# 198         -1                 95        volvo         four        sedan
# 199         -1                 95        volvo         four        sedan
# 200         -1                 95        volvo         four        sedan
#
#     drive-wheels engine-location  wheel-base  length  width  ...  length_std2  \
# ...

# %%
df.to_csv('output/autos_data_limpia.csv')
